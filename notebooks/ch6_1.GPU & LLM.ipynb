# %% [markdown]
# 실행 위치: Google Colab

# %% [markdown]
# # 1. vllm 라이브러리 설치

# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# Out:
# downloading uv 0.9.24 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!

# %%
# !uv pip install --system vllm==0.11.0 torch==2.8.0 transformers==4.57.6

# %% [markdown]
# # 2. 모델 로드
#  - 모델 로드 중 실패 발생시 제보 부탁드립니다. (Colab 기본 라이브러리 버전과 충돌 발생 가능성 있음)

# %%
# !vllm serve Qwen/Qwen3-1.7B > vllm_server.log 2>&1 &

# %%
# !cat vllm_server.log
# Out:
# INFO 01-10 12:27:25 [__init__.py:216] Automatically detected platform cuda.
# 2026-01-10 12:27:29.028540: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768048049.282734     882 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768048049.350054     882 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768048049.856814     882 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768048049.856878     882 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768048049.856887     882 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768048049.856891     882 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-10 12:27:29.903151: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# (APIServer pid=882) INFO 01-10 12:27:46 [api_server.py:1839] vLLM API server version 0.11.0
# (APIServer pid=882) INFO 01-10 12:27:46 [utils.py:233] non-default args: {'model_tag': 'Qwen/Qwen3-0.6B'}
# (APIServer pid=882) INFO 01-10 12:28:05 [model.py:547] Resolved architecture: Qwen3ForCausalLM
# (APIServer pid=882) `torch_dtype` is deprecated! Use `dtype` instead!
# (APIServer pid=882) WARNING 01-10 12:28:05 [model.py:1682] Your device 'Tesla T4' (with compute capability 7.5) doesn't support torch.bfloat16. Falling back to torch.float16 for compatibility.
# (APIServer pid=882) WARNING 01-10 12:28:05 [model.py:1733] Casting torch.bfloat16 to torch.float16.
# (APIServer pid=882) INFO 01-10 12:28:05 [model.py:1510] Using max model len 40960
# (APIServer pid=882) INFO 01-10 12:28:08 [scheduler.py:205] Chunked prefill is enabled with max_num_batched_tokens=2048.
# INFO 01-10 12:28:14 [__init__.py:216] Automatically detected platform cuda.
# 2026-01-10 12:28:16.100472: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768048096.122005    1165 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768048096.130837    1165 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768048096.145993    1165 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768048096.146017    1165 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768048096.146028    1165 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768048096.146031    1165 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# (EngineCore_DP0 pid=1165) INFO 01-10 12:28:24 [core.py:644] Waiting for init message from front-end.
# (EngineCore_DP0 pid=1165) INFO 01-10 12:28:24 [core.py:77] Initializing a V1 LLM engine (v0.11.0) with config: model='Qwen/Qwen3-0.6B', speculative_config=None, tokenizer='Qwen/Qwen3-0.6B', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=40960, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=Qwen/Qwen3-0.6B, enable_prefix_caching=True, chunked_prefill_enabled=True, pooler_config=None, compilation_config={"level":3,"debug_dump_path":"","cache_dir":"","backend":"","custom_ops":[],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output","vllm.mamba_mixer2","vllm.mamba_mixer","vllm.short_conv","vllm.linear_attention","vllm.plamo2_mamba_mixer","vllm.gdn_attention","vllm.sparse_attn_indexer"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"enable_auto_functionalized_v2":false},"inductor_passes":{},"cudagraph_mode":[2,1],"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"use_inductor_graph_partition":false,"pass_config":{},"max_capture_size":512,"local_cache_dir":null}
# (EngineCore_DP0 pid=1165) ERROR 01-10 12:28:25 [fa_utils.py:57] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# (EngineCore_DP0 pid=1165) INFO 01-10 12:28:27 [parallel_state.py:1208] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# (EngineCore_DP0 pid=1165) WARNING 01-10 12:28:27 [topk_topp_sampler.py:66] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (EngineCore_DP0 pid=1165) INFO 01-10 12:28:27 [gpu_model_runner.py:2602] Starting to load model Qwen/Qwen3-0.6B...
# (EngineCore_DP0 pid=1165) INFO 01-10 12:28:28 [gpu_model_runner.py:2634] Loading model from scratch...
# (EngineCore_DP0 pid=1165) INFO 01-10 12:28:28 [cuda.py:372] Using FlexAttention backend on V1 engine.
# (EngineCore_DP0 pid=1165) INFO 01-10 12:28:29 [weight_utils.py:392] Using model weights format ['*.safetensors']
# (EngineCore_DP0 pid=1165) INFO 01-10 12:28:36 [weight_utils.py:413] Time spent downloading weights for Qwen/Qwen3-0.6B: 7.806374 seconds
# (EngineCore_DP0 pid=1165) INFO 01-10 12:28:36 [weight_utils.py:450] No model.safetensors.index.json found in remote.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:01<00:00,  1.51s/it]
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:01<00:00,  1.51s/it]
# (EngineCore_DP0 pid=1165)
# (EngineCore_DP0 pid=1165) INFO 01-10 12:28:38 [default_loader.py:267] Loading weights took 1.55 seconds
# (EngineCore_DP0 pid=1165) INFO 01-10 12:28:39 [gpu_model_runner.py:2653] Model loading took 1.1201 GiB and 10.126584 seconds
# (EngineCore_DP0 pid=1165) INFO 01-10 12:28:48 [backends.py:548] Using cache directory: /root/.cache/vllm/torch_compile_cache/5c259b38e1/rank_0_0/backbone for vLLM's torch.compile
# (EngineCore_DP0 pid=1165) INFO 01-10 12:28:48 [backends.py:559] Dynamo bytecode transform time: 8.07 s
# (EngineCore_DP0 pid=1165) [rank0]:W0110 12:28:49.534000 1165 torch/_inductor/utils.py:1436] [0/0] Not enough SMs to use max_autotune_gemm mode
# (EngineCore_DP0 pid=1165) INFO 01-10 12:28:53 [backends.py:197] Cache the graph for dynamic shape for later use
# (EngineCore_DP0 pid=1165) INFO 01-10 12:29:18 [backends.py:218] Compiling a graph for dynamic shape takes 30.38 s
# (EngineCore_DP0 pid=1165) INFO 01-10 12:29:26 [monitor.py:34] torch.compile takes 38.45 s in total
# (EngineCore_DP0 pid=1165) INFO 01-10 12:29:28 [gpu_worker.py:298] Available KV cache memory: 10.72 GiB
# (EngineCore_DP0 pid=1165) INFO 01-10 12:29:28 [kv_cache_utils.py:1087] GPU KV cache size: 100,384 tokens
# (EngineCore_DP0 pid=1165) INFO 01-10 12:29:28 [kv_cache_utils.py:1091] Maximum concurrency for 40,960 tokens per request: 2.45x
# (EngineCore_DP0 pid=1165) WARNING 01-10 12:29:28 [gpu_model_runner.py:3663] CUDAGraphMode.FULL_AND_PIECEWISE is not supported with FlexAttentionMetadataBuilder backend (support: AttentionCGSupport.NEVER); setting cudagraph_mode=PIECEWISE because attention is compiled piecewise
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100%|██████████| 67/67 [00:03<00:00, 19.95it/s]
# (EngineCore_DP0 pid=1165) INFO 01-10 12:29:33 [gpu_model_runner.py:3480] Graph capturing finished in 5 secs, took 0.45 GiB
# (EngineCore_DP0 pid=1165) INFO 01-10 12:29:33 [core.py:210] init engine (profile, create kv cache, warmup model) took 54.11 seconds
# (APIServer pid=882) INFO 01-10 12:29:34 [loggers.py:147] Engine 000: vllm cache_config_info with initialization after num_gpu_blocks is: 6274
# (APIServer pid=882) INFO 01-10 12:29:35 [api_server.py:1634] Supported_tasks: ['generate']
# (APIServer pid=882) WARNING 01-10 12:29:35 [model.py:1389] Default sampling parameters have been overridden by the model's Hugging Face generation config recommended from the model creator. If this is not intended, please relaunch vLLM instance with `--generation-config vllm`.
# (APIServer pid=882) INFO 01-10 12:29:35 [serving_responses.py:137] Using default chat sampling params from model: {'temperature': 0.6, 'top_k': 20, 'top_p': 0.95}
# (APIServer pid=882) INFO 01-10 12:29:35 [serving_chat.py:139] Using default chat sampling params from model: {'temperature': 0.6, 'top_k': 20, 'top_p': 0.95}
# (APIServer pid=882) INFO 01-10 12:29:35 [serving_completion.py:76] Using default completion sampling params from model: {'temperature': 0.6, 'top_k': 20, 'top_p': 0.95}
# (APIServer pid=882) INFO 01-10 12:29:35 [api_server.py:1912] Starting vLLM API server 0 on http://0.0.0.0:8000
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:34] Available routes are:
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /openapi.json, Methods: HEAD, GET
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /docs, Methods: HEAD, GET
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /docs/oauth2-redirect, Methods: HEAD, GET
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /redoc, Methods: HEAD, GET
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /health, Methods: GET
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /load, Methods: GET
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /ping, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /ping, Methods: GET
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /tokenize, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /detokenize, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /v1/models, Methods: GET
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /version, Methods: GET
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /v1/responses, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /v1/responses/{response_id}, Methods: GET
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /v1/responses/{response_id}/cancel, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /v1/chat/completions, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /v1/completions, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /v1/embeddings, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /pooling, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /classify, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /score, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /v1/score, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /v1/audio/transcriptions, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /v1/audio/translations, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /rerank, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /v1/rerank, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /v2/rerank, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /scale_elastic_ep, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /is_scaling_elastic_ep, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /invocations, Methods: POST
# (APIServer pid=882) INFO 01-10 12:29:35 [launcher.py:42] Route: /metrics, Methods: GET
# (APIServer pid=882) INFO:     Started server process [882]
# (APIServer pid=882) INFO:     Waiting for application startup.
# (APIServer pid=882) INFO:     Application startup complete.

# %%
# !curl http://localhost:8000/v1/chat/completions \
    -H "Content-Type: application/json" \
    -d '{ \
        "messages": [{"role": "user", "content": "do you know kimchi?"}], \
        "max_tokens": 100, \
        "temperature": 0.8 \
    }'
# Out:
# {"id":"chatcmpl-f2e4c7b6a91f440993faa5ea9760c7e0","object":"chat.completion","created":1768049773,"model":"Qwen/Qwen3-0.6B","choices":[{"index":0,"message":{"role":"assistant","content":"<think>\nOkay, the user asked if I know kimchi. First, I need to confirm that I have knowledge about kimchi. Since I am an AI assistant, I can provide information on kimchi. I should explain that kimchi is a traditional Chinese food made from fermented ingredients, and maybe mention some of its key ingredients like cabbage, garlic, and soy sauce. Also, I can talk about how it's enjoyed in various cuisines, not just in China. I should keep the response","refusal":null,"annotations":null,"audio":null,"function_call":null,"tool_calls":[],"reasoning_content":null},"logprobs":null,"finish_reason":"length","stop_reason":null,"token_ids":null}],"service_tier":null,"system_fingerprint":null,"usage":{"prompt_tokens":14,"total_tokens":114,"completion_tokens":100,"prompt_tokens_details":null},"prompt_logprobs":null,"prompt_token_ids":null,"kv_transfer_params":null}
