# %% [markdown]
# 실행 위치: Google Colab

# %% [markdown]
# # 1. 임베딩 모델 로드

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("upskyy/bge-m3-korean")

# %% [markdown]
# # 2. 모델 구조 보기

# %%
print(model)
print('-----------------------')
print(model[0].auto_model)

xlm_roberta_model = model[0].auto_model

# %%
print(xlm_roberta_model.encoder.layer[3].attention.self.query.weight)

# %%
print(xlm_roberta_model.encoder.layer[3].attention.self.query.weight.shape)
